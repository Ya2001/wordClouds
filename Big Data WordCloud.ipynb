# %%
url = 'https://en.wikipedia.org/wiki/Big_data'

# %%
import requests

# %%
text = requests.get(url).content.decode('utf-8')
print(text[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Big data - Wikipedia</title>
# <script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled";(function(){var cookie=document.cookie.match(/(?:^|; )enwikimwclientprefs=([^;

# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    script = False
    res = ""
    def handle_starttag(self, tag, attrs):
        if tag.lower() in ["script","style"]:
            self.script = True
    def handle_endtag(self, tag):
        if tag.lower() in ["script","style"]:
            self.script = False
    def handle_data(self, data):
        if str.strip(data)=="" or self.script:
            return
        self.res += ' '+data.replace('[ edit ]','')

parser = MyHTMLParser()
parser.feed(text)
text = parser.res
print(text[:1000])
# Out:
#  Big data - Wikipedia Jump to content Main menu Main menu move to sidebar hide
# 		Navigation
# 	 Main page Contents Current events Random article About Wikipedia Contact us Donate
# 		Contribute
# 	 Help Learn to edit Community portal Recent changes Upload file Languages Language links are at the top of the page across from the title. Search Search Create account Log in Personal tools Create account Log in
# 		Pages for logged out editors  learn more Contributions Talk Contents move to sidebar hide (Top) 1 Definition Toggle Definition subsection 1.1 Big data vs. business intelligence 2 Characteristics 3 Architecture 4 Technologies 5 Applications Toggle Applications subsection 5.1 Government 5.2 International development 5.2.1 Benefits 5.2.2 Challenges 5.3 Finance 5.4 Healthcare 5.5 Education 5.6 Media 5.7 Insurance 5.8 Internet of things (IoT) 5.9 Information technology 6 Case studies Toggle Case studies subsection 6.1 Government 6.1.1 China 6.1.2 India 6.1.3 Israel 6.1.4 United Kingdom 6.1.

# %%
import sys
# !{sys.executable} -m pip install nlp_rake
# Out:
# Requirement already satisfied: nlp_rake in /Users/akshay/miniconda3/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: langdetect>=1.0.8 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from nlp_rake) (1.0.9)
# Requirement already satisfied: regex>=2018.6.6 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from nlp_rake) (2023.6.3)
# Requirement already satisfied: numpy>=1.14.4 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from nlp_rake) (1.25.0)
# Requirement already satisfied: pyrsistent>=0.14.2 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from nlp_rake) (0.19.3)
# Requirement already satisfied: six in /Users/akshay/miniconda3/lib/python3.10/site-packages (from langdetect>=1.0.8->nlp_rake) (1.16.0)

# %%
import nlp_rake
extractor = nlp_rake.Rake(max_words=2,min_freq=3,min_chars=5)
res = extractor.apply(text)
res
# Out:
# [('big data', 4.0),
#  ('data sets', 4.0),
#  ('machine learning', 4.0),
#  ('latin america', 4.0),
#  ('computer-aided diagnosis', 4.0),
#  ('data flow', 4.0),
#  ('scientific reports', 4.0),
#  ('wayback machine', 4.0),
#  ('washington post', 4.0),
#  ('english version', 4.0),
#  ('unsourced statements', 4.0),
#  ('data management', 3.916666666666667),
#  ('artificial intelligence', 3.909090909090909),
#  ('predictive analytics', 3.8421052631578947),
#  ('citation needed', 3.833333333333333),
#  ('data collected', 3.769230769230769),
#  ('business intelligence', 3.7552447552447554),
#  ('^ kitchin', 3.7386363636363633),
#  ('promotional source', 3.7142857142857144),
#  ('york times', 3.6923076923076925),
#  ('financial times', 3.6923076923076925),
#  ('international journal', 3.6842105263157894),
#  ('cite journal', 3.6842105263157894),
#  ('unstructured data', 3.625),
#  ('national archives', 3.583333333333333),
#  ('structured data', 3.571428571428571),
#  ('large amount', 3.5238095238095237),
#  ('data analysis', 3.4761904761904763),
#  ('marketing analytics', 3.4671052631578947),
#  ('ontological characteristics', 3.4545454545454546),
#  ('international development', 3.4210526315789473),
#  ('analytics', 1.8421052631578947),
#  ('large', 1.8095238095238095),
#  ('research', 1.7727272727272727),
#  ('collected', 1.7692307692307692),
#  ('systems', 1.75),
#  ('technology', 1.75),
#  ('health', 1.7272727272727273),
#  ('journal', 1.6842105263157894),
#  ('information', 1.6829268292682926),
#  ('social', 1.6666666666666667),
#  ('unstructured', 1.625),
#  ('mapreduce', 1.625),
#  ('applications', 1.625),
#  ('marketing', 1.625),
#  ('search', 1.6),
#  ('structured', 1.5714285714285714),
#  ('challenges', 1.5625),
#  ('process', 1.5555555555555556),
#  ('media', 1.5454545454545454),
#  ('processing', 1.5384615384615385),
#  ('scientists', 1.5),
#  ('sources', 1.5),
#  ('databases', 1.5),
#  ('potential', 1.5),
#  ('study', 1.5),
#  ('companies', 1.5),
#  ('26 datasets', 1.5),
#  ('analysis', 1.4761904761904763),
#  ('science', 1.4761904761904763),
#  ('technologies', 1.4615384615384615),
#  ('healthcare', 1.4545454545454546),
#  ('characteristics', 1.4545454545454546),
#  ('privacy', 1.4545454545454546),
#  ('google', 1.4545454545454546),
#  ('tools', 1.4285714285714286),
#  ('results', 1.4285714285714286),
#  ('approaches', 1.4285714285714286),
#  ('government', 1.4285714285714286),
#  ('field', 1.4285714285714286),
#  ('approach', 1.4285714285714286),
#  ('problems', 1.4285714285714286),
#  ('development', 1.4210526315789473),
#  ('generated', 1.4),
#  ('framework', 1.4),
#  ('institutions', 1.4),
#  ('difficult', 1.4),
#  ('content', 1.4),
#  ('services', 1.4),
#  ('understanding', 1.4),
#  ('theory', 1.4),
#  ('communication', 1.4),
#  ('things', 1.375),
#  ('internet', 1.368421052631579),
#  ('future', 1.3636363636363635),
#  ('developed', 1.3333333333333333),
#  ('access', 1.3333333333333333),
#  ('survey', 1.3333333333333333),
#  ('society', 1.3),
#  ('number', 1.2857142857142858),
#  ('years', 1.2857142857142858),
#  ('23andme', 1.2857142857142858),
#  ('complex', 1.25),
#  ('based', 1.25),
#  ('effectively', 1.25),
#  ('question', 1.25),
#  ('hundreds', 1.25),
#  ('included', 1.25),
#  ('concepts', 1.25),
#  ('compared', 1.25),
#  ('element', 1.25),
#  ('focus', 1.25),
#  ('hadoop', 1.25),
#  ('practitioners', 1.25),
#  ('people', 1.25),
#  ('hilbert', 1.25),
#  ('countries', 1.25),
#  ('finance', 1.25),
#  ('china', 1.25),
#  ('perspective', 1.25),
#  ('berkeley', 1.25),
#  ('funding', 1.25),
#  ('algorithms', 1.25),
#  ('mcardle', 1.25),
#  ('volume', 1.2307692307692308),
#  ('users', 1.2),
#  ('analyzed', 1.2),
#  ('nature', 1.2),
#  ('researchers', 1.2),
#  ('aspect', 1.2),
#  ('medicine', 1.2),
#  ('articles', 1.2),
#  ('model', 1.2),
#  ('review', 1.2),
#  ('velocity', 1.1428571428571428),
#  ('store', 1.1428571428571428),
#  ('terms', 1.1428571428571428),
#  ('world', 1.1428571428571428),
#  ('university', 1.125),
#  ('variety', 1.0),
#  ('veracity', 1.0),
#  ('create', 1.0),
#  ('capture', 1.0),
#  ('advertising', 1.0),
#  ('areas', 1.0),
#  ('biology', 1.0),
#  ('update', 1.0),
#  ('ability', 1.0),
#  ('semi-structured', 1.0),
#  ('forms', 1.0),
#  ('integration', 1.0),
#  ('qualities', 1.0),
#  ('represents', 1.0),
#  ('video', 1.0),
#  ('frequency', 1.0),
#  ('handling', 1.0),
#  ('order', 1.0),
#  ('retrieved', 1.0),
#  ('queries', 1.0),
#  ('gathered', 1.0),
#  ('mike2', 1.0),
#  ('demand', 1.0),
#  ('means', 1.0),
#  ('considered', 1.0),
#  ('innovation', 1.0),
#  ('governments', 1.0),
#  ('suggests', 1.0),
#  ('opportunities', 1.0),
#  ('challenge', 1.0),
#  ('working', 1.0),
#  ('concerned', 1.0),
#  ('efficiently', 1.0),
#  ('clients', 1.0),
#  ('level', 1.0),
#  ('types', 1.0),
#  ('understand', 1.0),
#  ('consumers', 1.0),
#  ('collection', 1.0),
#  ('population', 1.0),
#  ('israel', 1.0),
#  ('replication', 1.0),
#  ('march 2014', 1.0),
#  ('amplab', 1.0),
#  ('communicate', 1.0),
#  ('twitter', 1.0),
#  ('critiques', 1.0),
#  ('matzat', 1.0),
#  ('biosciences', 1.0),
#  ('policing', 1.0),
#  ('bibcode', 1.0),
#  ('2011sci', 1.0),
#  ('1126/science', 1.0),
#  ('archived', 1.0),
#  ('original', 1.0),
#  ('london', 1.0),
#  ('evolution', 1.0),
#  ('1016/j', 1.0),
#  ('charles', 1.0),
#  ('gavin', 1.0),
#  ('exploring', 1.0),
#  ('1177/2053951716631130', 1.0),
#  ('arxiv', 1.0),
#  ('https', 1.0),
#  ('//doi', 1.0),
#  ('org/10', 1.0),
#  ('//www', 1.0),
#  ('caribbean', 1.0),
#  ('forbes', 1.0),
#  ('wired', 1.0),
#  ('andrew', 1.0)]

# %%
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/akshay/miniconda3/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: numpy>=1.20 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: cycler>=0.10 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

def plot(pair_list):
    k,v = zip(*pair_list)
    plt.bar(range(len(k)),v)
    plt.xticks(range(len(k)),k,rotation='vertical')
    plt.show()

plot(res)

# %%
# !{sys.executable} -m pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp310-cp310-macosx_10_9_x86_64.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib in /Users/akshay/miniconda3/lib/python3.10/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: pillow in /Users/akshay/miniconda3/lib/python3.10/site-packages (from wordcloud) (10.0.0)
# Requirement already satisfied: numpy>=1.6.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from wordcloud) (1.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.40.0)
# Requirement already satisfied: six>=1.5 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc = WordCloud(background_color='white',width=800,height=600)
plt.figure(figsize=(15,7))
plt.imshow(wc.generate_from_frequencies({ k:v for k,v in res }))

# %%
plt.figure(figsize=(15,7))
plt.imshow(wc.generate(text))
