# %%
url = 'https://en.wikipedia.org/wiki/Machine_learning'

# %%
import requests

# %%
text = requests.get(url).content.decode('utf-8')
print(text[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>Machine learning - Wikipedia</title>
# <script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled";(function(){var cookie=document.cookie.match(/(?:^|; )enwikimwclientpr

# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    script = False
    res = ""
    def handle_starttag(self, tag, attrs):
        if tag.lower() in ["script","style"]:
            self.script = True
    def handle_endtag(self, tag):
        if tag.lower() in ["script","style"]:
            self.script = False
    def handle_data(self, data):
        if str.strip(data)=="" or self.script:
            return
        self.res += ' '+data.replace('[ edit ]','')

parser = MyHTMLParser()
parser.feed(text)
text = parser.res
print(text[:1000])
# Out:
#  Machine learning - Wikipedia Jump to content Main menu Main menu move to sidebar hide
# 		Navigation
# 	 Main page Contents Current events Random article About Wikipedia Contact us Donate
# 		Contribute
# 	 Help Learn to edit Community portal Recent changes Upload file Languages Language links are at the top of the page across from the title. Search Search Create account Log in Personal tools Create account Log in
# 		Pages for logged out editors  learn more Contributions Talk Contents move to sidebar hide (Top) 1 Overview 2 History and relationships to other fields Toggle History and relationships to other fields subsection 2.1 Artificial intelligence 2.2 Data mining 2.3 Generalization 2.4 Statistics 2.5 Physics 3 Theory 4 Approaches Toggle Approaches subsection 4.1 Supervised learning 4.2 Unsupervised learning 4.3 Semi-supervised learning 4.4 Reinforcement learning 4.5 Dimensionality reduction 4.6 Other types 4.6.1 Self-learning 4.6.2 Feature learning 4.6.3 Sparse dictionary learning 4.6.4

# %%
import sys
# !{sys.executable} -m pip install nlp_rake
# Out:
# Collecting nlp_rake
#   Downloading nlp_rake-0.0.2-py3-none-any.whl (30 kB)
# Collecting langdetect>=1.0.8
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 3.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting regex>=2018.6.6
#   Downloading regex-2023.6.3-cp310-cp310-macosx_10_9_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting numpy>=1.14.4
#   Downloading numpy-1.25.0-cp310-cp310-macosx_10_9_x86_64.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 4.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyrsistent>=0.14.2 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from nlp_rake) (0.19.3)
# Requirement already satisfied: six in /Users/akshay/miniconda3/lib/python3.10/site-packages (from langdetect>=1.0.8->nlp_rake) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=d184362d51445327e8d56d6265c004425dbc683b0981ca9709d9da100b67ab2f
#   Stored in directory: /Users/akshay/Library/Caches/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: regex, numpy, langdetect, nlp_rake
# Successfully installed langdetect-1.0.9 nlp_rake-0.0.2 numpy-1.25.0 regex-2023.6.3

# %%
import nlp_rake
extractor = nlp_rake.Rake(max_words=2,min_freq=3,min_chars=5)
res = extractor.apply(text)
res
# Out:
# [('data mining', 4.0),
#  ('polynomial time', 4.0),
#  ('main article', 4.0),
#  ('dimensionality reduction', 4.0),
#  ('anomaly detection', 4.0),
#  ('data set', 4.0),
#  ('bayesian networks', 4.0),
#  ('gaussian processes', 4.0),
#  ('language corpora', 4.0),
#  ('mcgraw hill', 4.0),
#  ('prentice hall', 4.0),
#  ('mit press', 4.0),
#  ('wayback machine', 3.9722222222222223),
#  ('artificial neuron', 3.966666666666667),
#  ('retrieved 2018-11-25', 3.9615384615384617),
#  ('statistical learning', 3.948717948717949),
#  ('feature learning', 3.948717948717949),
#  ('reinforcement learning', 3.948717948717949),
#  ('deep learning', 3.948717948717949),
#  ('machine learning', 3.920940170940171),
#  ('pattern recognition', 3.909090909090909),
#  ('neural networks', 3.888888888888889),
#  ('retrieved 2018-08-20', 3.878205128205128),
#  ('artificial intelligence', 3.875757575757576),
#  ('speech recognition', 3.857142857142857),
#  ('bayesian network', 3.857142857142857),
#  ('supervised learning', 3.8487179487179484),
#  ('explicitly programmed', 3.8),
#  ('biological brain', 3.8),
#  ('isbn 978-0-262-01243-0', 3.8),
#  ('unsupervised learning', 3.782051282051282),
#  ('medical diagnostics', 3.75),
#  ('random variables', 3.75),
#  ('outlier detection', 3.75),
#  ('international conference', 3.75),
#  ('ieee transactions', 3.75),
#  ('artificial neurons', 3.7444444444444445),
#  ('retrieved 2022-01-17', 3.7393162393162394),
#  ('training data', 3.7142857142857144),
#  ('training set', 3.7142857142857144),
#  ('make predictions', 3.7),
#  ('statistical physics', 3.666666666666667),
#  ('mathematical model', 3.6333333333333333),
#  ('genetic algorithms', 3.6047430830039526),
#  ('modern approach', 3.6),
#  ('computer vision', 3.598039215686274),
#  ('genetic algorithm', 3.5202020202020203),
#  ('knowledge discovery', 3.5128205128205128),
#  ('training examples', 3.3392857142857144),
#  ('information theory', 3.2714285714285714),
#  ('machine', 1.9722222222222223),
#  ('learning', 1.9487179487179487),
#  ('regression', 1.7692307692307692),
#  ('computer', 1.7647058823529411),
#  ('research', 1.7142857142857142),
#  ('training', 1.7142857142857142),
#  ('related', 1.7),
#  ('predictions', 1.7),
#  ('information', 1.7),
#  ('algorithms', 1.6956521739130435),
#  ('methods', 1.6666666666666667),
#  ('discovery', 1.6666666666666667),
#  ('model', 1.6333333333333333),
#  ('representation', 1.625),
#  ('examples', 1.625),
#  ('systems', 1.625),
#  ('algorithm', 1.6111111111111112),
#  ('approach', 1.6),
#  ('function', 1.6),
#  ('science', 1.6),
#  ('perform', 1.5833333333333333),
#  ('theory', 1.5714285714285714),
#  ('based', 1.5714285714285714),
#  ('models', 1.5555555555555556),
#  ('environment', 1.5555555555555556),
#  ('optimization', 1.5454545454545454),
#  ('biases', 1.5454545454545454),
#  ('relationships', 1.5),
#  ('tasks', 1.5),
#  ('classification', 1.5),
#  ('robert', 1.5),
#  ('input', 1.4615384615384615),
#  ('system', 1.4444444444444444),
#  ('application', 1.4285714285714286),
#  ('called', 1.4285714285714286),
#  ('racist', 1.4285714285714286),
#  ('journal', 1.4),
#  ('approaches', 1.4),
#  ('program', 1.4),
#  ('represented', 1.4),
#  ('accuracy', 1.4),
#  ('self-learning', 1.4),
#  ('categories', 1.4),
#  ('decisions', 1.3333333333333333),
#  ('problem', 1.3333333333333333),
#  ('researchers', 1.3333333333333333),
#  ('databases', 1.3333333333333333),
#  ('terms', 1.3333333333333333),
#  ('learned', 1.3333333333333333),
#  ('outputs', 1.3333333333333333),
#  ('process', 1.3333333333333333),
#  ('typically', 1.3333333333333333),
#  ('field', 1.2941176470588236),
#  ('learn', 1.2857142857142858),
#  ('applied', 1.2857142857142858),
#  ('improve', 1.25),
#  ('developed', 1.25),
#  ('trained', 1.25),
#  ('complexity', 1.25),
#  ('complex', 1.25),
#  ('overfitting', 1.25),
#  ('signal', 1.25),
#  ('inputs', 1.25),
#  ('changing', 1.25),
#  ('compute', 1.25),
#  ('people', 1.25),
#  ('stuart', 1.25),
#  ('norvig', 1.25),
#  ('christopher', 1.25),
#  ('2018-08-21', 1.25),
#  ('output', 1.2222222222222223),
#  ('applications', 1.2),
#  ('performance', 1.2),
#  ('predict', 1.2),
#  ('observations', 1.2),
#  ('result', 1.2),
#  ('peter', 1.2),
#  ('class', 1.1666666666666667),
#  ('study', 1.1428571428571428),
#  ('found', 1.125),
#  ('features', 1.1111111111111112),
#  ('introduction', 1.1111111111111112),
#  ('statistics', 1.0714285714285714),
#  ('original', 1.0266666666666666),
#  ('archived', 1.0135135135135136),
#  ('limitations', 1.0),
#  ('experience', 1.0),
#  ('ability', 1.0),
#  ('order', 1.0),
#  ('medicine', 1.0),
#  ('cases', 1.0),
#  ('respect', 1.0),
#  ('question', 1.0),
#  ('quest', 1.0),
#  ('leading', 1.0),
#  ('prediction', 1.0),
#  ('evaluated', 1.0),
#  ('instances', 1.0),
#  ('generalization', 1.0),
#  ('michael', 1.0),
#  ('context', 1.0),
#  ('hypothesis', 1.0),
#  ('addition', 1.0),
#  ('types', 1.0),
#  ('clustering', 1.0),
#  ('survey', 1.0),
#  ('members', 1.0),
#  ('images', 1.0),
#  ('bioinformatics', 1.0),
#  ('connection', 1.0),
#  ('layers', 1.0),
#  ('ethics', 1.0),
#  ('david', 1.0),
#  ('martin', 1.0),
#  ('springer', 1.0),
#  ('citeseerx 10', 1.0),
#  ('proceedings', 1.0),
#  ('andrew', 1.0),
#  ('2023-01-17', 1.0),
#  ('bibcode', 1.0),
#  ('1016/j', 1.0),
#  ('cybernetics', 1.0),
#  ('arxiv', 1.0),
#  ('james', 1.0),
#  ('ritter', 1.0),
#  ('cambridge', 1.0),
#  ('2022-01-18', 1.0)]

# %%
# !{sys.executable} -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp310-cp310-macosx_10_12_x86_64.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 6.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.0 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: numpy>=1.20 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (1.25.0)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.0-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 kB 3.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.3 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.40.0-cp310-cp310-macosx_10_9_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.4 MB/s eta 0:00:0000:01:00:01
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.0-cp310-cp310-macosx_10_10_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 8.2 MB/s eta 0:00:0000:0100:01m
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.0-cp310-cp310-macosx_10_9_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.6/243.6 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.5 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.40.0 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-10.0.0 pyparsing-3.1.0

# %%
import matplotlib.pyplot as plt

def plot(pair_list):
    k,v = zip(*pair_list)
    plt.bar(range(len(k)),v)
    plt.xticks(range(len(k)),k,rotation='vertical')
    plt.show()

plot(res)

# %%
# !{sys.executable} -m pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp310-cp310-macosx_10_9_x86_64.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib in /Users/akshay/miniconda3/lib/python3.10/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: pillow in /Users/akshay/miniconda3/lib/python3.10/site-packages (from wordcloud) (10.0.0)
# Requirement already satisfied: numpy>=1.6.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from wordcloud) (1.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.40.0)
# Requirement already satisfied: six>=1.5 in /Users/akshay/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc = WordCloud(background_color='white',width=800,height=600)
plt.figure(figsize=(15,7))
plt.imshow(wc.generate_from_frequencies({ k:v for k,v in res }))

# %%
plt.figure(figsize=(15,7))
plt.imshow(wc.generate(text))
